# %% [markdown]
# # Convert to a standardized version of dataframe
#
# A converter to convert data frame to a standard format for carpoolsim:
# 1. Traffic network links
# 2. Traffic network nodes
# 3. Traffic TAZs (polygons)
# 4. Traffic demands

# %%
import time
import copy
import os
import sys

import numpy as np
import pandas as pd
import geopandas as gpd

# %load_ext autoreload
# %autoreload 2
pd.options.display.max_columns = None  # display all columns

# %%
# need to set this environmental path everytime you moves the project root folder
os.environ['project_root'] = '/Users/geekduck/Dropbox/gt_survey'

sys.path.append(
    os.environ['project_root']
)

# %%
from carpoolsim.basic_settings import *

# %%
# load traffic network data
tazs_raw = gpd.read_file(os.environ["taz"])
df_nodes_raw = gpd.read_file(os.environ['network_nodes'])
df_links_raw = gpd.read_file(os.environ['network_links'])

# %%
from carpoolsim.dataclass.traffic_network import (
    TrafficNetworkLink,
    TrafficNetworkNode,
    TrafficAnalysisZone,
)

# %%
# clean node object
node_name_map = {
    "N": "nid",
    "lat": "lat",
    "lon": "lon",
    "X": "x",
    "Y": "y",
    "geometry": "geometry"
}
df_nodes_raw = df_nodes_raw.rename(columns=node_name_map)

df_nodes_lst = []
for index, row in df_nodes_raw.iterrows():
    df_nodes_lst.append(
        TrafficNetworkNode(row["nid"], row["lon"], row["lat"], row["x"], row["y"], row["geometry"])
    )

# %%
# clean link object
link_name_map = {
    "A": "a",
    "B": "b",
    "DISTANCE": "distance",
    "FACTYPE": "factype",
    "geometry": "geometry",
    "SPEED_LIMI": "speed_limit"
}
df_links_raw = df_links_raw.rename(columns=link_name_map)
df_links_raw["a"] = df_links_raw["a"].astype(str)
df_links_raw["b"] = df_links_raw["b"].astype(str)
df_links_raw["a_b"] = df_links_raw["a"] + "_" + df_links_raw["b"]


df_links_lst = []
for index, row in df_links_raw.iterrows():
    df_links_lst.append(
        TrafficNetworkLink(
            row["a"], row["b"], row["a_b"],
            row["distance"], row["factype"], row["speed_limit"],
            row["geometry"]
        )
    )

# %%
# clean taz object
taz_name_map = {
    "OBJECTID": "taz_id",
    "COUNTY": "group_id",
    "geometry": "geometry",
}
tazs_raw = tazs_raw.rename(columns=taz_name_map)


tazs_lst = []
for index, row in tazs_raw.iterrows():
    tazs_lst.append(
        TrafficAnalysisZone(
            row["taz_id"],
            row["group_id"],
            row["geometry"],
        )
    )

# %%
# convert data sets base to data frames
df_nodes = gpd.GeoDataFrame(df_nodes_lst)
df_links = gpd.GeoDataFrame(df_links_lst)
tazs = gpd.GeoDataFrame(tazs_lst)

# %%
print(tazs.shape)
print(df_nodes.shape)
print(df_links.shape)
# Out:
# (5873, 3)
# (27524, 6)
# (75289, 7)

# %%
# store cleaned results to shapefiles
tazs.to_file(
    os.path.join(os.environ['data_inputs'], "cleaned", "tazs.shp")
)
df_nodes.to_file(
    os.path.join(os.environ['data_inputs'], "cleaned", "nodes.shp")
)
df_links.to_file(
    os.path.join(os.environ['data_inputs'], "cleaned", "links.shp")
)
# Out:
# /var/folders/d2/ff61f5qd5y70wqh32zc2prvc0000gn/T/ipykernel_84950/1918336773.py:8: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   df_links.to_file(

# %% [markdown]
# ### Prepare pnr stations

# %%
from carpoolsim.dataclass.parking_lots import (
    ParkAndRideStation
)
from carpoolsim.dataclass.travel_demands import (
    TripDemand
)

# %%
pnr_lots = gpd.read_file(os.environ['parking_lots'])

# %%
pnr_lots.head(2)
# Out:
#    OBJECTID                          NAME            CITY  SPACES  \
# 0        76  MARTA - INDIAN CREEK STATION  Stone Mountain    2350
# 1        78       Hewatt Road park & ride      Snellville     125
#
#                                  GlobalID StreetNumb PostalCode  \
# 0  {46FF823F-E6E7-4597-B5B7-3BEC503B47A8}       3901      30083
# 1  {CCDA4DB1-A240-4013-A8F9-23741EAD99FF}       2191      30039
#
#          StreetName Publish                    geometry
# 0  Durham Park Road     Yes  POINT (-84.22903 33.76839)
# 1         Hewatt Rd     Yes  POINT (-84.05962 33.83902)

# %%
pnr_name_map = {
    "OBJECTID": "station_id",
    "NAME": "name",
    "SPACES": "capacity",
    "geometry": "geometry"
}
pnr_lots = pnr_lots.rename(columns=pnr_name_map)

pnr_lots['lon'] = pnr_lots.geometry.x
pnr_lots['lat'] = pnr_lots.geometry.y

# %%
pnr_lst = []
for index, row in pnr_lots.iterrows():
    pnr_lst.append(
        ParkAndRideStation(
            row["station_id"], row["name"],
            row["lon"], row["lat"], row["capacity"],
            row["geometry"]
        )
    )

# %%
pnrs = gpd.GeoDataFrame(pnr_lst)

# %%
pnrs.to_file(
    os.path.join(os.environ['data_inputs'], "cleaned", "pnrs.shp")
)

# %% [markdown]
# ## Prepare traffic demands
# For trip, need to add:
# - spatial information
# - temporal information

# %%
gt_survey = pd.read_csv(os.environ['trip_demands'], index_col=0)

# %%
gt_survey["trip_id"] = gt_survey.index

# %%
# a special input
gt_survey.sample(2)
# Out:
#              StartDate           EndDate      Status  Progress  \
# 1353  10/31/2022 15:44  10/31/2022 16:33  IP Address        13
# 31    10/31/2022 14:48  10/31/2022 14:53  IP Address       100
#
#       Duration..in.seconds.  Finished      RecordedDate         ResponseId  \
# 1353                   2938     False   11/7/2022 14:44  R_3Jaa59yHv1fTrS0
# 31                      298      True  10/31/2022 14:53  R_WvZQyWSwEah6XAZ
#
#      DistributionChannel UserLanguage  Q66                    Q73 Q73_2_TEXT  \
# 1353               email           EN   No                    NaN        NaN
# 31                 email           EN  Yes  Other, please specify        NaN
#
#                                              Q73_5_TEXT  \
# 1353                                                NaN
# 31    Fixed route, so only use when Shuttle seems de...
#
#                                                      Q2  Q68  Q67  \
# 1353  I live off campus and work or attend class at ...  NaN  NaN
# 31    I live off campus and work or attend class at ...  NaN  NaN
#
#                 Q3 Q3_6_TEXT             Q5             Q45  ZIPCODE  \
# 1353           NaN       NaN            NaN             NaN      NaN
# 31    Staff member       NaN  40-59 minutes  11 to 20 miles  30033.0
#
#                                             Q56_1  \
# 1353                                          NaN
# 31    Campus transit (Stinger, Stingerette, etc.)
#
#                                             Q56_2  \
# 1353                                          NaN
# 31    Campus transit (Stinger, Stingerette, etc.)
#
#                                             Q56_3  \
# 1353                                          NaN
# 31    Campus transit (Stinger, Stingerette, etc.)
#
#                                             Q56_4  \
# 1353                                          NaN
# 31    Campus transit (Stinger, Stingerette, etc.)
#
#                                             Q56_5     Q10     Q11 Q12_1 Q12_2  \
# 1353                                          NaN     NaN     NaN   NaN   NaN
# 31    Campus transit (Stinger, Stingerette, etc.)  8:30am  4:30pm   NaN   NaN
#
#      Q12_3 Q12_4 Q12_5 Q12_6 Q12_7 Q12_8 Q12_9 Q12_10 Q12_11 Q12_12 Q12_13  \
# 1353   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN    NaN    NaN
# 31     NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN    NaN    NaN
#
#      Q12_18 Q12_14 Q12_15 Q12_16 Q12_17 Q12_17_TEXT Q13_1 Q13_2 Q13_3  \
# 1353    NaN    NaN    NaN    NaN    NaN         NaN   NaN   NaN   NaN
# 31      NaN    NaN    NaN    NaN    NaN         NaN   NaN   NaN   NaN
#
#      Q13_1_TEXT  Q13_2_TEXT Q13_3_TEXT Q14_1 Q14_2 Q14_3 Q14_1_TEXT  \
# 1353        NaN         NaN        NaN   NaN   NaN   NaN        NaN
# 31          NaN         NaN        NaN   NaN   NaN   NaN        NaN
#
#      Q14_2_TEXT  Q14_3_TEXT  Q15  Q16 Q16_3_TEXT  Q69 Q69_6_TEXT  Q17  Q18  \
# 1353        NaN         NaN  NaN  NaN        NaN  NaN        NaN  NaN  NaN
# 31          NaN         NaN  NaN  NaN        NaN  NaN        NaN  NaN  NaN
#
#       Q19  Q55 Q20_1 Q20_2 Q20_3 Q20_4 Q20_5 Q20_6 Q20_7 Q20_8 Q20_9 Q20_10  \
# 1353  NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN
# 31    NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN
#
#      Q20_11 Q20_13 Q20_14 Q20_16 Q20_17 Q20_18 Q20_19 Q20_20 Q20_21 Q20_22  \
# 1353    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 31      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#      Q20_22_TEXT  Q25 Q25_14_TEXT  Q64  Q26 Q26_16_TEXT  Q27  Q28  Q29 Q30_1  \
# 1353         NaN  NaN         NaN  NaN  NaN         NaN  NaN  NaN  NaN   NaN
# 31           NaN  NaN         NaN  NaN  NaN         NaN  NaN  NaN  NaN   NaN
#
#      Q30_2 Q30_3 Q30_4 Q30_5 Q30_6 Q30_7 Q30_8 Q30_12 Q30_10 Q30_11 Q32_1  \
# 1353   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN    NaN   NaN
# 31     NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN    NaN   NaN
#
#      Q32_2 Q32_3 Q32_4 Q32_5                                  Q34_1  \
# 1353   NaN   NaN   NaN   NaN                                    NaN
# 31     NaN   NaN   NaN   NaN  Yes, but I have NOT used this program
#
#                                       Q34_2  \
# 1353                                    NaN
# 31    Yes, but I have NOT used this program
#
#                                    Q34_3                               Q34_4  \
# 1353                                 NaN                                 NaN
# 31    No, I am not aware of this program  No, I am not aware of this program
#
#                                    Q34_5                               Q34_6  \
# 1353                                 NaN                                 NaN
# 31    No, I am not aware of this program  No, I am not aware of this program
#
#                                       Q34_7  \
# 1353                                    NaN
# 31    Yes, but I have NOT used this program
#
#                                       Q34_8  \
# 1353                                    NaN
# 31    Yes, but I have NOT used this program
#
#                                       Q34_9  \
# 1353                                    NaN
# 31    Yes, but I have NOT used this program
#
#                                  Q34_10                              Q34_11  \
# 1353                                NaN                                 NaN
# 31    Yes, and I have used this program  No, I am not aware of this program
#
#                                      Q34_12  \
# 1353                                    NaN
# 31    Yes, but I have NOT used this program
#
#                                   Q34_13  \
# 1353                                 NaN
# 31    No, I am not aware of this program
#
#                                      Q34_14  \
# 1353                                    NaN
# 31    Yes, but I have NOT used this program
#
#                                   Q34_15                              Q34_16  \
# 1353                                 NaN                                 NaN
# 31    No, I am not aware of this program  No, I am not aware of this program
#
#       Q47  Q59  Q51  Q49 Q49_5_TEXT  Q48  Q50  Q61  Q62  Q65  Q35  Q38  \
# 1353  NaN  NaN  NaN  NaN        NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 31    NaN   No  NaN  NaN        NaN  NaN  NaN  NaN  NaN  NaN  NaN  Yes
#
#       trip_id
# 1353     1353
# 31         31

# %%
# filter out nan values for zip code
gt_survey = gt_survey[gt_survey['ZIPCODE'].notna()]
gt_survey["ZIPCODE"] = gt_survey["ZIPCODE"].astype(int)

# %%
gt_survey.Q2.unique()
# Out:
# array(['I live off campus and work or attend class at the main Georgia Tech campus in Midtown Atlanta',
#        'I live on campus in campus housing (residence halls)',
#        'I live on campus in Greek housing'], dtype=object)

# %%
# Q10: home to work time
# Q11: work to home time
gt_survey.Q10.unique()
# Out:
# array(['7:30am', '8:00am', '8:30am', '11:00am', '9:00am', '10:00am',
#        '7:00am', '9:30am', '8:00pm', '9:00pm', '9:30pm', '7:00pm',
#        '11:30am', '6:00am', nan, '2:00pm', '6:30am', '12:00pm', '10:30am',
#        '12:30pm', '12:00am - 5:30am', '3:30pm', '6:30pm', '1:00pm',
#        '1:30pm', '4:00pm', '7:30pm', '5:00pm', '3:00pm', '10:30pm',
#        '8:30pm', '2:30pm'], dtype=object)

# %%
filt = (gt_survey.Q10.notna())
gt_survey = gt_survey[gt_survey.Q10.notna()]
print(gt_survey.shape)
# Out:
# (1545, 143)

# %%
# If earlier than 5:30 AM, change it to 5:30 AM
gt_survey['Q10'] = gt_survey['Q10'].str.replace(
    "12:00am - 5:30am",
    "5:30am"
)

# %%
# 2023-01-01 is the pseudo date
depart_time = "2023-01-01 " + gt_survey.Q10

gt_survey['depart_time'] = pd.to_datetime(
    depart_time,
    format=r"%Y-%m-%d %I:%M%p"
)

# %%
def extract_newmins(df_row):
    tm = (df_row["depart_time"] - pd.to_datetime("2023-01-01")
         ).total_seconds() / 60
    return tm

gt_survey['newmin'] = gt_survey['depart_time'] - pd.to_datetime("2023-01-01")
gt_survey['newmin'] = gt_survey.apply(extract_newmins, axis=1)
gt_survey.sample(2)
# Out:
#             StartDate          EndDate      Status  Progress  \
# 842   11/3/2022 11:00  11/3/2022 11:09  IP Address       100
# 2051   11/7/2022 7:42   11/7/2022 7:48  IP Address        90
#
#       Duration..in.seconds.  Finished     RecordedDate         ResponseId  \
# 842                     524      True  11/3/2022 11:09  R_3DuUDAlFz6LUkvs
# 2051                    315     False  11/14/2022 7:42  R_8ibfhiinfulcIP7
#
#      DistributionChannel UserLanguage Q66  Q73 Q73_2_TEXT Q73_5_TEXT  \
# 842                email           EN  No  NaN        NaN        NaN
# 2051               email           EN  No  NaN        NaN        NaN
#
#                                                      Q2  Q68  Q67  \
# 842   I live off campus and work or attend class at ...  NaN  NaN
# 2051  I live off campus and work or attend class at ...  NaN  NaN
#
#                             Q3 Q3_6_TEXT             Q5             Q45  \
# 842   Graduate/postdoc student       NaN  20-39 minutes   4 to 10 miles
# 2051              Staff member       NaN  20-39 minutes  11 to 20 miles
#
#       ZIPCODE                                        Q56_1  \
# 842     30318                 Telecommute (work from home)
# 2051    30030  Drive alone (car, truck, motorcycle, moped)
#
#                                             Q56_2  \
# 842   Drive alone (car, truck, motorcycle, moped)
# 2051  Drive alone (car, truck, motorcycle, moped)
#
#                                             Q56_3  \
# 842                  Telecommute (work from home)
# 2051  Drive alone (car, truck, motorcycle, moped)
#
#                                             Q56_4  \
# 842   Drive alone (car, truck, motorcycle, moped)
# 2051  Drive alone (car, truck, motorcycle, moped)
#
#                                             Q56_5      Q10     Q11 Q12_1  \
# 842   Drive alone (car, truck, motorcycle, moped)  10:30am  5:30pm   NaN
# 2051  Drive alone (car, truck, motorcycle, moped)   7:30am  4:00pm   NaN
#
#                                               Q12_2 Q12_3 Q12_4 Q12_5 Q12_6  \
# 842                                             NaN   NaN   NaN   NaN   NaN
# 2051  Don't like to depend on others for carpooling   NaN   NaN   NaN   NaN
#
#      Q12_7                                      Q12_8 Q12_9  \
# 842    NaN                                        NaN   NaN
# 2051   NaN  Need my car at work for personal business   NaN
#
#                                               Q12_10 Q12_11  \
# 842   Transit options are not available where I live    NaN
# 2051                                             NaN    NaN
#
#                       Q12_12               Q12_13                  Q12_18  \
# 842                      NaN  Poor bicycle access  Poor pedestrian access
# 2051  Transit takes too long                  NaN                     NaN
#
#      Q12_14           Q12_15                             Q12_16 Q12_17  \
# 842     NaN  Safety concerns  Anything else takes too much time    NaN
# 2051    NaN              NaN  Anything else takes too much time    NaN
#
#      Q12_17_TEXT Q13_1 Q13_2 Q13_3 Q13_1_TEXT  Q13_2_TEXT Q13_3_TEXT Q14_1  \
# 842          NaN   NaN   NaN   NaN        NaN         NaN        NaN   NaN
# 2051         NaN   NaN   NaN   NaN        NaN         NaN        NaN   NaN
#
#      Q14_2 Q14_3 Q14_1_TEXT Q14_2_TEXT  Q14_3_TEXT  Q15  Q16 Q16_3_TEXT  Q69  \
# 842    NaN   NaN        NaN        NaN         NaN  NaN  NaN        NaN  NaN
# 2051   NaN   NaN        NaN        NaN         NaN  NaN  NaN        NaN  NaN
#
#      Q69_6_TEXT Q17  Q18  Q19  Q55                   Q20_1 Q20_2 Q20_3 Q20_4  \
# 842         NaN  No  NaN  NaN  NaN  Ability to telecommute   NaN   NaN   NaN
# 2051        NaN  No  NaN  NaN  NaN  Ability to telecommute   NaN   NaN   NaN
#
#      Q20_5 Q20_6 Q20_7 Q20_8 Q20_9  \
# 842    NaN   NaN   NaN   NaN   NaN
# 2051   NaN   NaN   NaN   NaN   NaN
#
#                                                  Q20_10 Q20_11 Q20_13 Q20_14  \
# 842                                                 NaN    NaN    NaN    NaN
# 2051  Increased financial incentives (e.g., transit ...    NaN    NaN    NaN
#
#      Q20_16 Q20_17 Q20_18 Q20_19 Q20_20 Q20_21 Q20_22 Q20_22_TEXT  \
# 842     NaN    NaN    NaN    NaN    NaN    NaN    NaN         NaN
# 2051    NaN    NaN    NaN    NaN    NaN    NaN    NaN         NaN
#
#               Q25 Q25_14_TEXT  Q64  Q26 Q26_16_TEXT  Q27  Q28  Q29 Q30_1  \
# 842   Telecommute         NaN  NaN  NaN         NaN  NaN  NaN  NaN   NaN
# 2051  Telecommute         NaN  NaN  NaN         NaN  NaN  NaN  NaN   NaN
#
#      Q30_2 Q30_3 Q30_4 Q30_5 Q30_6 Q30_7 Q30_8 Q30_12 Q30_10 Q30_11 Q32_1  \
# 842    NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN    NaN   NaN
# 2051   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN    NaN   NaN
#
#      Q32_2 Q32_3 Q32_4 Q32_5                                  Q34_1  \
# 842    NaN   NaN   NaN   NaN  Yes, but I have NOT used this program
# 2051   NaN   NaN   NaN   NaN     No, I am not aware of this program
#
#                                       Q34_2  \
# 842   Yes, but I have NOT used this program
# 2051     No, I am not aware of this program
#
#                                       Q34_3  \
# 842   Yes, but I have NOT used this program
# 2051     No, I am not aware of this program
#
#                                       Q34_4  \
# 842   Yes, but I have NOT used this program
# 2051     No, I am not aware of this program
#
#                                    Q34_5                               Q34_6  \
# 842   No, I am not aware of this program  No, I am not aware of this program
# 2051  No, I am not aware of this program  No, I am not aware of this program
#
#                                       Q34_7  \
# 842   Yes, but I have NOT used this program
# 2051     No, I am not aware of this program
#
#                                       Q34_8  \
# 842   Yes, but I have NOT used this program
# 2051     No, I am not aware of this program
#
#                                       Q34_9  \
# 842   Yes, but I have NOT used this program
# 2051     No, I am not aware of this program
#
#                                   Q34_10  \
# 842    Yes, and I have used this program
# 2051  No, I am not aware of this program
#
#                                      Q34_11  \
# 842   Yes, but I have NOT used this program
# 2051     No, I am not aware of this program
#
#                                   Q34_12                              Q34_13  \
# 842    Yes, and I have used this program  No, I am not aware of this program
# 2051  No, I am not aware of this program  No, I am not aware of this program
#
#                                   Q34_14                              Q34_15  \
# 842   No, I am not aware of this program  No, I am not aware of this program
# 2051  No, I am not aware of this program  No, I am not aware of this program
#
#                                      Q34_16           Q47 Q59  Q51  Q49  \
# 842      No, I am not aware of this program   $50 to $100  No  NaN  NaN
# 2051  Yes, but I have NOT used this program  $100 to $150  No  NaN  NaN
#
#      Q49_5_TEXT  Q48  Q50  Q61  Q62  Q65  \
# 842         NaN  NaN  NaN  NaN  NaN  NaN
# 2051        NaN  NaN  NaN  NaN  NaN  NaN
#
#                                        Q35  Q38  trip_id         depart_time  \
# 842   Lower the cost of parking on campus.  Yes      842 2023-01-01 10:30:00
# 2051                                   NaN  NaN     2051 2023-01-01 07:30:00
#
#       newmin
# 842    630.0
# 2051   450.0

# %%
# package for querying zip code
import pgeocode

locator = pgeocode.Nominatim("us")
location = locator.query_postal_code(30310)
print((location.latitude, location.longitude))
# Out:
# (33.7278, -84.4232)

# %%
# extract longitude/latitude for all positions!
def extract_lon_lat(df_row):
    location = locator.query_postal_code(df_row["ZIPCODE"])
    return pd.Series({
        "longitude": location.longitude,
        "latitude": location.latitude
    })

gt_survey[["ori_lon", "ori_lat"]] = gt_survey.apply(extract_lon_lat, axis=1)
display(gt_survey.sample(2))
# Out:
#             StartDate           EndDate      Status  Progress  \
# 311  10/31/2022 16:59  10/31/2022 17:03  IP Address       100
# 60   10/31/2022 15:00  10/31/2022 15:06  IP Address       100
#
#      Duration..in.seconds.  Finished      RecordedDate         ResponseId  \
# 311                    194      True  10/31/2022 17:03  R_3lMIYHXUsvotdSi
# 60                     374      True  10/31/2022 15:06  R_Zei355ubxrBdMuR
#
#     DistributionChannel UserLanguage  Q66                          Q73  \
# 311               email           EN  Yes  Mostly use the TransLoc app
# 60                email           EN  Yes  Mostly use the TransLoc app
#
#     Q73_2_TEXT Q73_5_TEXT                                                 Q2  \
# 311        NaN        NaN  I live off campus and work or attend class at ...
# 60         NaN        NaN  I live off campus and work or attend class at ...
#
#      Q68  Q67                     Q3 Q3_6_TEXT                    Q5  \
# 311  NaN  NaN  Undergraduate student       NaN  less than 10 minutes
# 60   NaN  NaN         Faculty member       NaN        1 hour or more
#
#                     Q45  ZIPCODE                       Q56_1  \
# 311  fewer than 4 miles    30308                        Walk
# 60   more than 30 miles    30024  Commuter bus (GRTA Xpress)
#
#                           Q56_2                       Q56_3  \
# 311                         NaN                         NaN
# 60   Commuter bus (GRTA Xpress)  Commuter bus (GRTA Xpress)
#
#                           Q56_4                       Q56_5     Q10     Q11  \
# 311                         NaN                         NaN  8:00am  7:30pm
# 60   Commuter bus (GRTA Xpress)  Commuter bus (GRTA Xpress)  9:30pm  4:30pm
#
#     Q12_1 Q12_2 Q12_3 Q12_4 Q12_5 Q12_6 Q12_7 Q12_8 Q12_9 Q12_10 Q12_11  \
# 311   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN
# 60    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN
#
#     Q12_12 Q12_13 Q12_18 Q12_14 Q12_15 Q12_16 Q12_17 Q12_17_TEXT  \
# 311    NaN    NaN    NaN    NaN    NaN    NaN    NaN         NaN
# 60     NaN    NaN    NaN    NaN    NaN    NaN    NaN         NaN
#
#                    Q13_1 Q13_2 Q13_3 Q13_1_TEXT  Q13_2_TEXT Q13_3_TEXT Q14_1  \
# 311                  NaN   NaN   NaN        NaN         NaN        NaN   NaN
# 60   GRTA Xpress route #   NaN   NaN    412/414         NaN        NaN   NaN
#
#     Q14_2 Q14_3 Q14_1_TEXT Q14_2_TEXT  Q14_3_TEXT  Q15  Q16 Q16_3_TEXT    Q69  \
# 311   NaN   NaN        NaN        NaN         NaN  NaN  NaN        NaN    NaN
# 60    NaN   NaN        NaN        NaN         NaN  NaN  NaN        NaN  Drive
#
#     Q69_6_TEXT  Q17  Q18  Q19  Q55 Q20_1 Q20_2 Q20_3 Q20_4 Q20_5 Q20_6 Q20_7  \
# 311        NaN  NaN  NaN  NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 60         NaN  NaN  NaN  NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#     Q20_8 Q20_9 Q20_10 Q20_11 Q20_13 Q20_14 Q20_16 Q20_17 Q20_18 Q20_19  \
# 311   NaN   NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 60    NaN   NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#     Q20_20 Q20_21 Q20_22 Q20_22_TEXT  Q25 Q25_14_TEXT  Q64  Q26 Q26_16_TEXT  \
# 311    NaN    NaN    NaN         NaN  NaN         NaN  NaN  NaN         NaN
# 60     NaN    NaN    NaN         NaN  NaN         NaN  NaN  NaN         NaN
#
#      Q27  Q28  Q29 Q30_1 Q30_2 Q30_3 Q30_4 Q30_5 Q30_6 Q30_7 Q30_8 Q30_12  \
# 311  NaN  NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN
# 60   NaN  NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN
#
#     Q30_10 Q30_11 Q32_1 Q32_2 Q32_3 Q32_4 Q32_5  \
# 311    NaN    NaN   NaN   NaN   NaN   NaN   NaN
# 60     NaN    NaN   NaN   NaN   NaN   NaN   NaN
#
#                                   Q34_1                               Q34_2  \
# 311  No, I am not aware of this program  No, I am not aware of this program
# 60   No, I am not aware of this program  No, I am not aware of this program
#
#                                   Q34_3                               Q34_4  \
# 311  No, I am not aware of this program   Yes, and I have used this program
# 60   No, I am not aware of this program  No, I am not aware of this program
#
#                                      Q34_5  \
# 311  Yes, but I have NOT used this program
# 60      No, I am not aware of this program
#
#                                      Q34_6  \
# 311  Yes, but I have NOT used this program
# 60      No, I am not aware of this program
#
#                                      Q34_7  \
# 311  Yes, but I have NOT used this program
# 60   Yes, but I have NOT used this program
#
#                                      Q34_8  \
# 311  Yes, but I have NOT used this program
# 60       Yes, and I have used this program
#
#                                   Q34_9                              Q34_10  \
# 311  No, I am not aware of this program  No, I am not aware of this program
# 60   No, I am not aware of this program  No, I am not aware of this program
#
#                                  Q34_11  \
# 311  No, I am not aware of this program
# 60   No, I am not aware of this program
#
#                                     Q34_12  \
# 311  Yes, but I have NOT used this program
# 60   Yes, but I have NOT used this program
#
#                                  Q34_13                              Q34_14  \
# 311  No, I am not aware of this program  No, I am not aware of this program
# 60   No, I am not aware of this program  No, I am not aware of this program
#
#                                  Q34_15                              Q34_16  \
# 311  No, I am not aware of this program  No, I am not aware of this program
# 60   No, I am not aware of this program  No, I am not aware of this program
#
#      Q47 Q59  Q51  Q49 Q49_5_TEXT  Q48  Q50  Q61  Q62  Q65  \
# 311  NaN  No  NaN  NaN        NaN  NaN  NaN  NaN  NaN  NaN
# 60   NaN  No  NaN  NaN        NaN  NaN  NaN  NaN  NaN  NaN
#
#                                                    Q35  Q38  trip_id  \
# 311  I am a little concerned with the use of scoote...  Yes      311
# 60                                                 NaN  Yes       60
#
#             depart_time  newmin  ori_lon  ori_lat
# 311 2023-01-01 08:00:00   480.0 -84.3757  33.7718
# 60  2023-01-01 21:30:00  1290.0 -84.0262  34.0425

# %%
# add Geogia Tech as final destination
gt_survey["dest_lon"] = -84.397971
gt_survey["dest_lat"] = 33.775766

# %%
# clean results
trip_name_map = {
    "ori_lon": "orig_lon",
    "ori_lat": "orig_lat",
    "dest_lon": "dest_lon",
    "dest_lat": "dest_lat",
    "newmin": "new_min"
}

trips = gt_survey.rename(columns=trip_name_map)

# %%
trips = gpd.GeoDataFrame(
    trips,
    geometry=gpd.points_from_xy(
        trips.orig_lon,
        trips.orig_lat
    ),
    crs="EPSG:4326"
)

# %%
trip_lst = []
for index, row in trips.iterrows():
    trip_lst.append(
        TripDemand(
            row["trip_id"],
            row["orig_lon"], row["orig_lat"],
            row["dest_lon"], row["dest_lat"],
            row["new_min"], row["geometry"],
        )
    )

# %%
trips = gpd.GeoDataFrame(trip_lst)
print(trips.shape)
# Out:
# (1545, 7)

# %%
trips.to_file(
    os.path.join(
        os.environ['data_inputs'], 
        "cleaned", 
        "trips.shp"
    )
)
